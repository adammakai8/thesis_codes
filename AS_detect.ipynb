# %% [markdown]
# Könyvtár pozíció alaphelyzetbe állítása (szükség esetén)

# %%
# %cd /Documents/Studies/diplomamunka/AS_Train/
# Out:
# D:\Documents\Studies\diplomamunka\AS_Train

# %% [markdown]
# Futtatással kapcsolatos konstansok

# %%
WORKING_DIR = '/Documents/Studies/diplomamunka/AS_Train'
DATASET_PATH = f'{WORKING_DIR}/datasets/mo_reszlet'
DATASETS = [
    'LUCAS2009_AS+',
    'LUCAS2009_AS-',
    'LUCAS2012_AS+',
    'LUCAS2012_AS-',
    'LUCAS2015_AS+',
    'LUCAS2015_AS-',
    'LUCAS2018_AS+',
    'LUCAS2018_AS-',
    ]

PROJECT_PATH = f'{WORKING_DIR}/runs/detect'

WEIGHTS_NAME = 'as4x200_std_large_best'

CONFIDENCE_THRESHOLD = 0.2

# %% [markdown]
# YOLOv5 setup

# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# %pip install -qr requirements.txt
# Out:
# D:\Documents\Studies\diplomamunka\AS_Train\yolov5
# fatal: destination path 'yolov5' already exists and is not an empty directory.
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Vizsgálandó mappákon végig iterálás, detekciók futtatása

# %%
for dataset in DATASETS:
    weights_path = f'{WORKING_DIR}/weights/{WEIGHTS_NAME}.pt'
    source_path = f'{DATASET_PATH}/{dataset}'

    # !python detect.py --weights $weights_path --img 640 --conf $CONFIDENCE_THRESHOLD --source $source_path --name $dataset --project $PROJECT_PATH --save-txt --save-csv --device 0
# Out:
# Streaming output truncated to the last 5000 lines.
# image 444/2000 D:\Documents\Studies\diplomamunka\AS_Train\datasets\mo_reszlet\LUCAS2015_AS-\2015_49482658N_N.jpg: 480x640 (no detections), 38.0ms
# image 445/2000 D:\Documents\Studies\diplomamunka\AS_Train\datasets\mo_reszlet\LUCAS2015_AS-\2015_49482712N_N.jpg: 480x640 (no detections), 38.0ms
# image 446/2000 D:\Documents\Studies\diplomamunka\AS_Train\datasets\mo_reszlet\LUCAS2015_AS-\2015_49482766N_N.jpg: 480x640 (no detections), 38.0ms
# image 447/2000 D:\Documents\Studies\diplomamunka\AS_Train\datasets\mo_reszlet\LUCAS2015_AS-\2015_49502578P_N.jpg: 480x640 (no detections), 38.0ms
# image 448/2000 D:\Documents\Studies\diplomamunka\AS_Train\datasets\mo_reszlet\LUCAS2015_AS-\2015_49502596N_N.jpg: 480x640 (no detections), 38.0ms
# image 449/2000 D:\Documents\Studies\diplomamunka\AS_Train\datasets\mo_reszlet\LUCAS2015_AS-\2015_49502596P_N.jpg: 480x640 (no detections), 38.0ms
# ...
